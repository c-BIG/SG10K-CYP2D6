# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# # Load consensus_df

# %%
consensus_df = pd.read_parquet("output/2_consensus.parquet")
consensus_df
# Out:
#      sample_id  stellarpgx_copy_number                        aldy
# 0      WHB3374                     2.0                    [*1/*10]  \
# 1      WHB3375                     2.0              [*10/*36.ALDY]
# 2      WHB3376                     3.0          [*10/*36.ALDY+*10]
# 3      WHB3377                     3.0          [*10/*36.ALDY+*10]
# 4      WHB3378                     3.0          [*36.ALDY+*10/*41]
# ...        ...                     ...                         ...
# 1847   WHB5465                     2.0                     [*1/*1]
# 1848   WHB5466                     3.0  [*1+*36.ALDY/*36.ALDY+*10]
# 1849   WHB5467                     2.0                    [*1/*21]
# 1850   WHB5468                     2.0                     [*1/*1]
# 1851   WHB5469                     3.0           [*1/*36.ALDY+*10]
#
#                 cyrius     stellarpgx diplotype_consensus
# 0             [*1/*10]       [*1/*10]              *1/*10  \
# 1         [*5/*36+*10]      [*10/*36]             *10/*36
# 2        [*10/*36+*10]  [*10/*36+*10]         *10/*10+*36
# 3        [*10/*36+*10]  [*10/*36+*10]         *10/*10+*36
# 4        [*41/*36+*10]  [*41/*36+*10]         *10+*36/*41
# ...                ...            ...                 ...
# 1847           [*1/*1]        [*1/*1]               *1/*1
# 1848  [*1/*36+*36+*10]   [*1/*36+*10]                None
# 1849          [*1/*21]       [*1/*21]              *1/*21
# 1850           [*1/*1]        [*1/*1]               *1/*1
# 1851      [*1/*36+*10]   [*1/*36+*10]          *1/*10+*36
#
#       diplotype_caller_agreement        callers_in_agreement novel_allele
# 0                       1.000000  [aldy, cyrius, stellarpgx]           []  \
# 1                       0.666667          [aldy, stellarpgx]           []
# 2                       1.000000  [aldy, cyrius, stellarpgx]           []
# 3                       1.000000  [aldy, cyrius, stellarpgx]           []
# 4                       1.000000  [aldy, cyrius, stellarpgx]           []
# ...                          ...                         ...          ...
# 1847                    1.000000  [aldy, cyrius, stellarpgx]           []
# 1848                         NaN                          []           []
# 1849                    1.000000  [aldy, cyrius, stellarpgx]           []
# 1850                    1.000000  [aldy, cyrius, stellarpgx]           []
# 1851                    1.000000  [aldy, cyrius, stellarpgx]           []
#
#      haplotype_consensus genetic_sex genetic_ancestry
# 0              [*1, *10]      female                C
# 1             [*10, *36]        male                C
# 2         [*10, *10+*36]      female                C
# 3         [*10, *10+*36]      female                C
# 4         [*41, *10+*36]        male                C
# ...                  ...         ...              ...
# 1847            [*1, *1]      female                C
# 1848       [*1, *10+*36]      female                C
# 1849           [*1, *21]      female                C
# 1850            [*1, *1]        male                I
# 1851       [*1, *10+*36]        male                C
#
# [1852 rows x 12 columns]

# %% [markdown]
# # Filter out potentially novel alleles, drop samples with no diplotype consensus and drop no_call

# %%
filt_df = (
    consensus_df[consensus_df["novel_allele"].apply(lambda x: len(x) == 0)]
    .dropna(subset=["diplotype_consensus"])
    .copy()
)
filt_df = filt_df.query("diplotype_consensus != 'no_call'")

# %% [markdown]
# # Aggregate by diplotype

# %%
diplotype_df = pd.DataFrame(
    {
        "AC": filt_df["diplotype_consensus"].value_counts(),
        "AF": filt_df["diplotype_consensus"].value_counts(normalize=True),
    }
)

for ancestry, ancestry_df in filt_df.groupby("genetic_ancestry"):
    ancestry_af_ac = {
        f"AC_{ancestry}": ancestry_df["diplotype_consensus"].value_counts(),
        f"AF_{ancestry}": ancestry_df["diplotype_consensus"].value_counts(
            normalize=True
        ),
    }
    # display(pd.DataFrame(ancestry_af_ac))
    diplotype_df = pd.concat([diplotype_df, pd.DataFrame(ancestry_af_ac)], axis=1)

diplotype_df = diplotype_df.fillna(0).reset_index(names="diplotype")
diplotype_df
# Out:
#           diplotype   AC        AF   AC_C      AF_C  AC_I      AF_I  AC_M
# 0        *1/*10+*36  235  0.162630  210.0  0.193015   2.0  0.012579  23.0  \
# 1   *10+*36/*10+*36  162  0.112111  150.0  0.137868   1.0  0.006289  11.0
# 2       *10/*10+*36  150  0.103806  130.0  0.119485   1.0  0.006289  19.0
# 3             *1/*1  118  0.081661   75.0  0.068934  23.0  0.144654  20.0
# 4            *1/*10  103  0.071280   71.0  0.065257   2.0  0.012579  30.0
# ..              ...  ...       ...    ...       ...   ...       ...   ...
# 83          *1x2/*4    1  0.000692    0.0  0.000000   1.0  0.006289   0.0
# 84          *35/*86    1  0.000692    0.0  0.000000   1.0  0.006289   0.0
# 85           *2/*14    1  0.000692    1.0  0.000919   0.0  0.000000   0.0
# 86           *1/*17    1  0.000692    0.0  0.000000   1.0  0.006289   0.0
# 87           *1/*21    1  0.000692    1.0  0.000919   0.0  0.000000   0.0
#
#         AF_M  AC_O  AF_O
# 0   0.117347   0.0   0.0
# 1   0.056122   0.0   0.0
# 2   0.096939   0.0   0.0
# 3   0.102041   0.0   0.0
# 4   0.153061   0.0   0.0
# ..       ...   ...   ...
# 83  0.000000   0.0   0.0
# 84  0.000000   0.0   0.0
# 85  0.000000   0.0   0.0
# 86  0.000000   0.0   0.0
# 87  0.000000   0.0   0.0
#
# [88 rows x 11 columns]

# %% [markdown]
# # Aggregate by haplotype

# %%
filt_hap_df = filt_df.copy()
filt_hap_df["haplotype"] = filt_hap_df["diplotype_consensus"].str.split("/")
filt_hap_df = filt_hap_df.explode("haplotype")

haplotype_df = pd.DataFrame(
    {
        "AC": filt_hap_df["haplotype"].value_counts(),
        "AF": filt_hap_df["haplotype"].value_counts(normalize=True),
    }
)

for ancestry, ancestry_df in filt_hap_df.groupby("genetic_ancestry"):
    ancestry_af_ac = {
        f"AC_{ancestry}": ancestry_df["haplotype"].value_counts(),
        f"AF_{ancestry}": ancestry_df["haplotype"].value_counts(normalize=True),
    }
    haplotype_df = pd.concat([haplotype_df, pd.DataFrame(ancestry_af_ac)], axis=1)

haplotype_df = haplotype_df.fillna(0).reset_index()
haplotype_df
# Out:
#    haplotype   AC        AF   AC_C      AF_C   AC_I      AF_I   AC_M
# 0    *10+*36  843  0.291696  753.0  0.346048   10.0  0.031447   80.0  \
# 1         *1  798  0.276125  555.0  0.255055  123.0  0.386792  119.0
# 2        *10  509  0.176125  397.0  0.182445   11.0  0.034591  101.0
# 3         *2  295  0.102076  192.0  0.088235   63.0  0.198113   38.0
# 4        *41  137  0.047405   82.0  0.037684   38.0  0.119497   17.0
# 5         *5  101  0.034948   70.0  0.032169   20.0  0.062893   11.0
# 6        *36   45  0.015571   40.0  0.018382    0.0  0.000000    5.0
# 7        *14   28  0.009689   27.0  0.012408    0.0  0.000000    1.0
# 8         *4   24  0.008304    0.0  0.000000   17.0  0.053459    7.0
# 9        *49   20  0.006920   19.0  0.008732    0.0  0.000000    1.0
# 10       *71   13  0.004498   10.0  0.004596    0.0  0.000000    3.0
# 11       *35   12  0.004152    7.0  0.003217    5.0  0.015723    0.0
# 12      *2x2   10  0.003460    7.0  0.003217    1.0  0.003145    2.0
# 13    *4+*68    9  0.003114    1.0  0.000460    8.0  0.025157    0.0
# 14      *1x2    9  0.003114    2.0  0.000919    4.0  0.012579    3.0
# 15       *43    5  0.001730    1.0  0.000460    4.0  0.012579    0.0
# 16       *21    4  0.001384    4.0  0.001838    0.0  0.000000    0.0
# 17       *86    4  0.001384    0.0  0.000000    4.0  0.012579    0.0
# 18       *94    3  0.001038    3.0  0.001379    0.0  0.000000    0.0
# 19       *39    3  0.001038    2.0  0.000919    0.0  0.000000    1.0
# 20      *113    2  0.000692    0.0  0.000000    2.0  0.006289    0.0
# 21       *33    2  0.000692    0.0  0.000000    2.0  0.006289    0.0
# 22       *65    2  0.000692    1.0  0.000460    0.0  0.000000    1.0
# 23      *111    2  0.000692    0.0  0.000000    1.0  0.003145    1.0
# 24      *112    1  0.000346    0.0  0.000000    1.0  0.003145    0.0
# 25        *3    1  0.000346    0.0  0.000000    0.0  0.000000    0.0
# 26       *52    1  0.000346    1.0  0.000460    0.0  0.000000    0.0
# 27        *7    1  0.000346    0.0  0.000000    1.0  0.003145    0.0
# 28      *133    1  0.000346    1.0  0.000460    0.0  0.000000    0.0
# 29       *17    1  0.000346    0.0  0.000000    1.0  0.003145    0.0
# 30        *9    1  0.000346    0.0  0.000000    1.0  0.003145    0.0
# 31       *15    1  0.000346    0.0  0.000000    0.0  0.000000    1.0
# 32     *4+*4    1  0.000346    0.0  0.000000    1.0  0.003145    0.0
# 33       *69    1  0.000346    1.0  0.000460    0.0  0.000000    0.0
#
#         AF_M  AC_O  AF_O
# 0   0.204082   0.0  0.00
# 1   0.303571   1.0  0.25
# 2   0.257653   0.0  0.00
# 3   0.096939   2.0  0.50
# 4   0.043367   0.0  0.00
# 5   0.028061   0.0  0.00
# 6   0.012755   0.0  0.00
# 7   0.002551   0.0  0.00
# 8   0.017857   0.0  0.00
# 9   0.002551   0.0  0.00
# 10  0.007653   0.0  0.00
# 11  0.000000   0.0  0.00
# 12  0.005102   0.0  0.00
# 13  0.000000   0.0  0.00
# 14  0.007653   0.0  0.00
# 15  0.000000   0.0  0.00
# 16  0.000000   0.0  0.00
# 17  0.000000   0.0  0.00
# 18  0.000000   0.0  0.00
# 19  0.002551   0.0  0.00
# 20  0.000000   0.0  0.00
# 21  0.000000   0.0  0.00
# 22  0.002551   0.0  0.00
# 23  0.002551   0.0  0.00
# 24  0.000000   0.0  0.00
# 25  0.000000   1.0  0.25
# 26  0.000000   0.0  0.00
# 27  0.000000   0.0  0.00
# 28  0.000000   0.0  0.00
# 29  0.000000   0.0  0.00
# 30  0.000000   0.0  0.00
# 31  0.002551   0.0  0.00
# 32  0.000000   0.0  0.00
# 33  0.000000   0.0  0.00

# %% [markdown]
# # Export TSV and parquet for both diplotype and haplotype tables

# %%
output_dir = Path("output")
dip_file_name = "3_diplotypes"
hap_file_name = "3_haplotypes"

if not output_dir.exists():
    output_dir.mkdir()

# Export diplotypes
diplotype_df.to_csv(output_dir / f"{dip_file_name}.tsv", sep="\t", index=False)
diplotype_df.to_parquet(output_dir / f"{dip_file_name}.parquet", index=False)

# Export haplotypes
haplotype_df.to_csv(output_dir / f"{hap_file_name}.tsv", sep="\t", index=False)
haplotype_df.to_parquet(output_dir / f"{hap_file_name}.parquet", index=False)
