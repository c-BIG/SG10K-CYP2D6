# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# # Load consensus_df and PharmGKB reference

# %%
consensus_df = pd.read_parquet("output/2_consensus.parquet")
# PharmGKB data
pgkb = pd.read_csv("/home/jupyter-yusuf/Consensus/data_viz/References/pgkb_haplotype_function.tsv", sep = "\t", dtype = {'activity_value': 'float64'})

# %%
consensus_df.head()
# Out:
#   sample_id  stellarpgx_copy_number                aldy         cyrius  \
# 0   WHB3374                     2.0            [*1/*10]       [*1/*10]
# 1   WHB3375                     2.0      [*10/*36.ALDY]   [*5/*36+*10]
# 2   WHB3376                     3.0  [*10/*36.ALDY+*10]  [*10/*36+*10]
# 3   WHB3377                     3.0  [*10/*36.ALDY+*10]  [*10/*36+*10]
# 4   WHB3378                     3.0  [*36.ALDY+*10/*41]  [*41/*36+*10]
#
#       stellarpgx diplotype_consensus  diplotype_caller_agreement  \
# 0       [*1/*10]              *1/*10                    1.000000
# 1      [*10/*36]             *10/*36                    0.666667
# 2  [*10/*36+*10]         *10/*10+*36                    1.000000
# 3  [*10/*36+*10]         *10/*10+*36                    1.000000
# 4  [*41/*36+*10]         *10+*36/*41                    1.000000
#
#          callers_in_agreement novel_allele haplotype_consensus genetic_sex  \
# 0  [aldy, cyrius, stellarpgx]           []           [*1, *10]      female
# 1          [aldy, stellarpgx]           []          [*10, *36]        male
# 2  [aldy, cyrius, stellarpgx]           []      [*10, *10+*36]      female
# 3  [aldy, cyrius, stellarpgx]           []      [*10, *10+*36]      female
# 4  [aldy, cyrius, stellarpgx]           []      [*41, *10+*36]        male
#
#   genetic_ancestry
# 0                C
# 1                C
# 2                C
# 3                C
# 4                C

# %%
filt_df = (
    consensus_df
    .dropna(subset=["diplotype_consensus"])
    .copy()
)

filt_df.query("diplotype_consensus == 'no_call'")
# Out:
#     sample_id  stellarpgx_copy_number                         aldy  cyrius  \
# 935   WHB4383                     5.0  [*36.ALDY+*10/*36.ALDY+*10]  [None]
#
#     stellarpgx diplotype_consensus  diplotype_caller_agreement  \
# 935     [None]             no_call                    0.666667
#
#      callers_in_agreement novel_allele haplotype_consensus genetic_sex  \
# 935  [cyrius, stellarpgx]           []        [None, None]      female
#
#     genetic_ancestry
# 935                C

# %% [markdown]
# # Filter out potentially novel alleles, drop samples with no diplotype consensus and drop no_call

# %%
# Still keeping the novel alleles if they passed the threshold
# [consensus_df["novel_allele"].apply(lambda x: len(x) == 0)]
filt_df = (
    consensus_df
    .dropna(subset=["diplotype_consensus"])
    .copy()
)
filt_df = filt_df.query("diplotype_consensus != 'no_call'")
filt_df.shape
# Out:
# (1503, 12)

# %%
filt_df[filt_df["diplotype_consensus"].str.contains(r'\*4(?!\d+)')]
# Out:
#      sample_id  stellarpgx_copy_number                        aldy  \
# 12     WHB3386                     2.0  [*41/*68+*4.021+rs3021084]
# 39     WHB3416                     2.0                   [*4C/*10]
# 164    WHB3552                     2.0                    [*4/*10]
# 433    WHB3858                     2.0                   [*4C/*10]
# 443    WHB3868                     2.0               [*4.021/*112]
# 449    WHB3874                     3.0            [*41/*68+*4.021]
# 457    WHB3883                     2.0                     [*1/*4]
# 480    WHB3907                     2.0                     [*2/*4]
# 487    WHB3914                     2.0                     [*1/*4]
# 519    WHB3946                     2.0                     [*1/*4]
# 655    WHB4092                     2.0                    [*4/*41]
# 673    WHB4112                     2.0                   [*13/*63]
# 677    WHB4117                     2.0                 [*1/*4.021]
# 678    WHB4118                     3.0                  [*1+*1/*4]
# 716    WHB4158                     2.0                    [*1/*4C]
# 763    WHB4207                     2.0                     [*1/*4]
# 765    WHB4209                     2.0                    [*1/*4C]
# 771    WHB4216                     2.0          [*2+rs75386357/*4]
# 801    WHB4246                     3.0                 [*1/*68+*4]
# 828    WHB4274                     2.0                     [*2/*4]
# 852    WHB4298                     2.0                   [*4C/*82]
# 879    WHB4326                     2.0                   [*4C/*86]
# 894    WHB4341                     2.0         [*1+rs28371704/*4C]
# 899    WHB4346                     3.0             [*1/*68+*4.021]
# 913    WHB4360                     3.0          [*4C/*36.ALDY+*10]
# 1066   WHB4539                     3.0                     [*1/*4]
# 1069   WHB4542                     2.0                    [*4/*10]
# 1073   WHB4546                     2.0                    [*2/*4C]
# 1116   WHB4589                     2.0                     [*1/*4]
# 1168   WHB4647                     2.0                    [*4/*41]
# 1187   WHB4667                     1.0                     [*4/*5]
# 1193   WHB4675                     2.0                    [*4/*41]
# 1256   WHB4743                     3.0                [*41/*68+*4]
# 1272   WHB4760                     3.0             [*2/*68+*4.021]
# 1295   WHB4784                     3.0             [*1/*68+*4.021]
# 1306   WHB4795                     3.0             [*1/*68+*4.021]
# 1313   WHB4803                     2.0                   [*4C/*86]
# 1458   WHB4953                     3.0           [*4/*36.ALDY+*10]
# 1605   WHB5111                     3.0            [*1/*4+*4N.ALDY]
# 1611   WHB5117                     3.0                [*4.021/*41]
# 1648   WHB5154                     2.0             [*1/*68+*4.021]
# 1708   WHB5218                     2.0                   [*4K/*41]
#
#               cyrius    stellarpgx diplotype_consensus  \
# 12      [*41/*68+*4]     [*136/*4]          *4+*68/*41
# 39          [*10/*4]      [*10/*4]              *4/*10
# 164         [*10/*4]      [*10/*4]              *4/*10
# 433         [*10/*4]      [*10/*4]              *4/*10
# 443        [*112/*4]     [*112/*4]             *4/*112
# 449     [*41/*68+*4]  [*41/*68+*4]          *4+*68/*41
# 457          [*1/*4]       [*1/*4]               *1/*4
# 480           [None]       [*2/*4]               *2/*4
# 487          [*1/*4]      [*10/*4]               *1/*4
# 519          [*1/*4]       [*1/*4]               *1/*4
# 655         [*4/*41]      [*4/*41]              *4/*41
# 673          [*2/*4]       [*2/*4]               *2/*4
# 677          [*1/*4]       [*4/*4]               *1/*4
# 678        [*1x2/*4]     [*4/*1x2]             *1x2/*4
# 716          [*1/*4]       [*1/*4]               *1/*4
# 763          [*1/*4]       [*1/*4]               *1/*4
# 765          [*1/*4]       [*1/*4]               *1/*4
# 771          [*2/*4]       [*2/*4]               *2/*4
# 801      [*1/*68+*4]  [*86/*68+*4]           *1/*4+*68
# 828          [*2/*4]       [*2/*4]               *2/*4
# 852         [*4/*82]      [*4/*82]              *4/*82
# 879          [*1/*4]      [*4/*86]              *4/*86
# 894          [*1/*4]       [*1/*4]               *1/*4
# 899      [*1/*68+*4]     [*1/*4x2]           *1/*4+*68
# 913     [*4/*36+*10]      [*10/*4]          *4/*10+*36
# 1066         [*1/*4]     [*1/*4x2]               *1/*4
# 1069        [*10/*4]      [*10/*4]              *4/*10
# 1073         [*2/*4]       [*2/*4]               *2/*4
# 1116         [*1/*4]       [*1/*4]               *1/*4
# 1168          [None]      [*4/*41]              *4/*41
# 1187         [*4/*5]       [*5/*4]               *4/*5
# 1193        [*4/*41]      [*4/*41]              *4/*41
# 1256    [*41/*68+*4]    [*41/*4x2]          *4+*68/*41
# 1272     [*2/*68+*4]   [*2/*68+*4]           *2/*4+*68
# 1295     [*1/*68+*4]     [*4/*4x2]           *1/*4+*68
# 1306     [*1/*68+*4]   [*1/*68+*4]           *1/*4+*68
# 1313         [*1/*4]      [*4/*86]              *4/*86
# 1458    [*4/*36+*10]      [*10/*4]          *4/*10+*36
# 1605  [*1/*4.013+*4]     [*1/*4x2]            *1/*4+*4
# 1611    [*41/*68+*4]  [*41/*68+*4]          *4+*68/*41
# 1648     [*1/*68+*4]       [*1/*4]           *1/*4+*68
# 1708        [*4/*41]      [*4/*41]              *4/*41
#
#       diplotype_caller_agreement        callers_in_agreement  \
# 12                      0.666667              [aldy, cyrius]
# 39                      1.000000  [aldy, cyrius, stellarpgx]
# 164                     1.000000  [aldy, cyrius, stellarpgx]
# 433                     1.000000  [aldy, cyrius, stellarpgx]
# 443                     1.000000  [aldy, cyrius, stellarpgx]
# 449                     1.000000  [aldy, cyrius, stellarpgx]
# 457                     1.000000  [aldy, cyrius, stellarpgx]
# 480                     0.666667          [aldy, stellarpgx]
# 487                     0.666667              [aldy, cyrius]
# 519                     1.000000  [aldy, cyrius, stellarpgx]
# 655                     1.000000  [aldy, cyrius, stellarpgx]
# 673                     0.666667        [cyrius, stellarpgx]
# 677                     0.666667              [aldy, cyrius]
# 678                     0.666667        [cyrius, stellarpgx]
# 716                     1.000000  [aldy, cyrius, stellarpgx]
# 763                     1.000000  [aldy, cyrius, stellarpgx]
# 765                     1.000000  [aldy, cyrius, stellarpgx]
# 771                     1.000000  [aldy, cyrius, stellarpgx]
# 801                     0.666667              [aldy, cyrius]
# 828                     1.000000  [aldy, cyrius, stellarpgx]
# 852                     1.000000  [aldy, cyrius, stellarpgx]
# 879                     0.666667          [aldy, stellarpgx]
# 894                     1.000000  [aldy, cyrius, stellarpgx]
# 899                     0.666667              [aldy, cyrius]
# 913                     0.666667              [aldy, cyrius]
# 1066                    0.666667              [aldy, cyrius]
# 1069                    1.000000  [aldy, cyrius, stellarpgx]
# 1073                    1.000000  [aldy, cyrius, stellarpgx]
# 1116                    1.000000  [aldy, cyrius, stellarpgx]
# 1168                    0.666667          [aldy, stellarpgx]
# 1187                    1.000000  [aldy, cyrius, stellarpgx]
# 1193                    1.000000  [aldy, cyrius, stellarpgx]
# 1256                    0.666667              [aldy, cyrius]
# 1272                    1.000000  [aldy, cyrius, stellarpgx]
# 1295                    0.666667              [aldy, cyrius]
# 1306                    1.000000  [aldy, cyrius, stellarpgx]
# 1313                    0.666667          [aldy, stellarpgx]
# 1458                    0.666667              [aldy, cyrius]
# 1605                    0.666667              [aldy, cyrius]
# 1611                    0.666667        [cyrius, stellarpgx]
# 1648                    0.666667              [aldy, cyrius]
# 1708                    1.000000  [aldy, cyrius, stellarpgx]
#
#             novel_allele haplotype_consensus genetic_sex genetic_ancestry
# 12    [aldy, stellarpgx]       [*41, *4+*68]        male                I
# 39                    []           [*10, *4]      female                M
# 164                   []           [*10, *4]        male                I
# 433                   []           [*10, *4]      female                M
# 443                   []          [*112, *4]      female                I
# 449                   []       [*41, *4+*68]      female                I
# 457                   []            [*1, *4]      female                M
# 480                   []            [*2, *4]      female                I
# 487         [stellarpgx]            [*1, *4]      female                I
# 519                   []            [*1, *4]        male                I
# 655                   []           [*4, *41]        male                I
# 673                   []            [*2, *4]      female                I
# 677                   []            [*1, *4]        male                M
# 678                   []          [None, *4]        male                I
# 716                   []            [*1, *4]        male                I
# 763                   []            [*1, *4]        male                M
# 765                   []            [*1, *4]        male                I
# 771   [aldy, stellarpgx]            [*2, *4]      female                I
# 801                   []        [*1, *4+*68]      female                I
# 828                   []            [*2, *4]        male                I
# 852         [stellarpgx]           [*4, *82]      female                I
# 879                   []           [*4, *86]        male                I
# 894               [aldy]            [*1, *4]      female                M
# 899                   []        [*1, *4+*68]      female                I
# 913         [stellarpgx]       [*4, *10+*36]        male                C
# 1066                  []            [*1, *4]        male                I
# 1069                  []           [*10, *4]      female                M
# 1073                  []            [*2, *4]        male                I
# 1116                  []            [*1, *4]        male                I
# 1168        [stellarpgx]           [*4, *41]      female                I
# 1187                  []            [*4, *5]      female                M
# 1193                  []           [*4, *41]        male                I
# 1256                  []       [*41, *4+*68]        male                I
# 1272                  []        [*2, *4+*68]      female                I
# 1295                  []        [*1, *4+*68]        male                I
# 1306                  []        [*1, *4+*68]        male                I
# 1313                  []           [*4, *86]      female                I
# 1458        [stellarpgx]       [*4, *10+*36]      female                C
# 1605                  []         [*1, *4+*4]        male                I
# 1611                  []       [*41, *4+*68]      female                I
# 1648                  []        [*1, *4+*68]      female                C
# 1708                  []           [*4, *41]        male                I

# %%
filt_df.groupby("diplotype_consensus")['stellarpgx_copy_number'].unique().head(30)
# Out:
# diplotype_consensus
# *1/*1                   [2.0, 3.0]
# *1/*10                  [2.0, 3.0]
# *1/*10+*36         [3.0, 2.0, 4.0]
# *1/*113                 [3.0, 2.0]
# *1/*14                  [2.0, 3.0]
# *1/*17                       [2.0]
# *1/*1x2                      [3.0]
# *1/*2                   [2.0, 3.0]
# *1/*21                       [2.0]
# *1/*2x2                      [3.0]
# *1/*33                       [2.0]
# *1/*35                       [2.0]
# *1/*36                       [2.0]
# *1/*4                   [2.0, 3.0]
# *1/*4+*4                     [3.0]
# *1/*4+*68               [3.0, 2.0]
# *1/*41                       [2.0]
# *1/*43                       [2.0]
# *1/*49                       [2.0]
# *1/*5                        [1.0]
# *1/*71                       [2.0]
# *1/*94                       [2.0]
# *10+*36/*10+*36    [4.0, 3.0, 5.0]
# *10+*36/*133                 [2.0]
# *10+*36/*14                  [3.0]
# *10+*36/*21                  [2.0]
# *10+*36/*35                  [3.0]
# *10+*36/*36                  [3.0]
# *10+*36/*41             [3.0, 2.0]
# *10+*36/*43                  [3.0]
# Name: stellarpgx_copy_number, dtype: object

# %% [markdown]
# # Aggregate by diplotype

# %%
diplotype_df = pd.DataFrame(
    {
        "AC": filt_df["diplotype_consensus"].value_counts(),
        "AF": filt_df["diplotype_consensus"].value_counts(normalize=True) * 100,
    }
)

for ancestry, ancestry_df in filt_df.groupby("genetic_ancestry"):
    ancestry_af_ac = {
        f"AC_{ancestry}": ancestry_df["diplotype_consensus"].value_counts(),
        f"AF_{ancestry}": ancestry_df["diplotype_consensus"].value_counts() / len(filt_df) * 100,
        f"AF_GA_{ancestry}": ancestry_df["diplotype_consensus"].value_counts(normalize=True) * 100,
        
    }
    # display(pd.DataFrame(ancestry_af_ac))
    diplotype_df = pd.concat([diplotype_df, pd.DataFrame(ancestry_af_ac)], axis=1)

diplotype_df = diplotype_df.fillna(0).reset_index(names="diplotype")
diplotype_df.head(10)
# Out:
#          diplotype   AC         AF   AC_C       AF_C    AF_GA_C  AC_I  \
# 0       *1/*10+*36  248  16.500333  223.0  14.836993  19.595782   2.0
# 1  *10+*36/*10+*36  164  10.911510  152.0  10.113107  13.356766   1.0
# 2      *10/*10+*36  152  10.113107  132.0   8.782435  11.599297   1.0
# 3            *1/*1  119   7.917498   76.0   5.056554   6.678383  23.0
# 4           *1/*10  111   7.385230   77.0   5.123087   6.766257   2.0
# 5            *1/*2   95   6.320692   53.0   3.526281   4.657293  29.0
# 6       *2/*10+*36   70   4.657352   57.0   3.792415   5.008787   3.0
# 7          *10/*10   54   3.592814   40.0   2.661344   3.514938   1.0
# 8           *2/*10   53   3.526281   41.0   2.727878   3.602812   4.0
# 9          *10/*36   44   2.927478   39.0   2.594810   3.427065   0.0
#
#        AF_I    AF_GA_I  AC_M      AF_M  AF_GA_M
# 0  0.133067   1.212121  23.0  1.530273     11.5
# 1  0.066534   0.606061  11.0  0.731870      5.5
# 2  0.066534   0.606061  19.0  1.264138      9.5
# 3  1.530273  13.939394  20.0  1.330672     10.0
# 4  0.133067   1.212121  32.0  2.129075     16.0
# 5  1.929474  17.575758  13.0  0.864937      6.5
# 6  0.199601   1.818182  10.0  0.665336      5.0
# 7  0.066534   0.606061  13.0  0.864937      6.5
# 8  0.266134   2.424242   8.0  0.532269      4.0
# 9  0.000000   0.000000   5.0  0.332668      2.5

# %% [markdown]
# # Function to retrieve the activity value and phenotype from the reference

# %%
def get_av(df, ref):    
    av = 0
    diplotype = df['diplotype'].split('/')
    for haplotype in diplotype:
        if haplotype in ref['haplotype'].values:
            av += ref.loc[ref['haplotype'] == haplotype, 'activity_value'].iloc[0]
                
    return av

@np.vectorize
def phenotype(row):
    if (0 == row):
        return 'PM'
    elif (0 < row <1.25):
        return 'IM' 
    elif (1.25 <= row <=2.25):
        return 'NM'
    elif (2.25 < row <15):
        return 'UM'
    else:
        return 'Indeterminate'

# %%
diplotype_df['activity_value'] = diplotype_df.apply(lambda x: get_av(x, pgkb), axis=1)
diplotype_df['phenotype'] = phenotype(diplotype_df['activity_value'])
# Out:
# /home/jupyter-yusuf/.conda/envs/cyp2d6/lib/python3.9/site-packages/numpy/lib/function_base.py:2412: RuntimeWarning: invalid value encountered in phenotype (vectorized)
#   outputs = ufunc(*inputs)

# %%
diplotype_df.head()
# Out:
#          diplotype   AC         AF   AC_C       AF_C    AF_GA_C  AC_I  \
# 0       *1/*10+*36  248  16.500333  223.0  14.836993  19.595782   2.0
# 1  *10+*36/*10+*36  164  10.911510  152.0  10.113107  13.356766   1.0
# 2      *10/*10+*36  152  10.113107  132.0   8.782435  11.599297   1.0
# 3            *1/*1  119   7.917498   76.0   5.056554   6.678383  23.0
# 4           *1/*10  111   7.385230   77.0   5.123087   6.766257   2.0
#
#        AF_I    AF_GA_I  AC_M      AF_M  AF_GA_M  activity_value phenotype
# 0  0.133067   1.212121  23.0  1.530273     11.5            1.25        NM
# 1  0.066534   0.606061  11.0  0.731870      5.5            0.50        IM
# 2  0.066534   0.606061  19.0  1.264138      9.5            0.50        IM
# 3  1.530273  13.939394  20.0  1.330672     10.0            2.00        NM
# 4  0.133067   1.212121  32.0  2.129075     16.0            1.25        NM

# %% [markdown]
# # Aggregate by haplotype

# %%
filt_hap_df = filt_df.copy()
filt_hap_df["haplotype"] = filt_hap_df["diplotype_consensus"].str.split("/")
filt_hap_df = filt_hap_df.explode("haplotype")

haplotype_df = pd.DataFrame(
    {
        "AC": filt_hap_df["haplotype"].value_counts(),
        "AF": filt_hap_df["haplotype"].value_counts(normalize=True) * 100,
    }
)

for ancestry, ancestry_df in filt_hap_df.groupby("genetic_ancestry"):
    ancestry_af_ac = {
        f"AC_{ancestry}": ancestry_df["haplotype"].value_counts(),
        f"AF_{ancestry}": ancestry_df["haplotype"].value_counts() / len(filt_hap_df) * 100,
        f"AF_GA_{ancestry}": ancestry_df["haplotype"].value_counts(normalize=True) * 100,
    }
    haplotype_df = pd.concat([haplotype_df, pd.DataFrame(ancestry_af_ac)], axis=1)

haplotype_df = haplotype_df.fillna(0).reset_index(names="haplotype")

# %% [markdown]
# Add activity values and function from pharmgkb

# %%
haplotype_df = pd.merge(haplotype_df, pgkb, on = "haplotype", how = "left")
haplotype_df.head(5)
# Out:
#   haplotype   AC         AF   AC_C       AF_C    AF_GA_C   AC_I      AF_I  \
# 0   *10+*36  866  28.809049  776.0  25.815037  34.094903   10.0  0.332668
# 1        *1  833  27.711244  587.0  19.527611  25.790861  124.0  4.125083
# 2       *10  529  17.598137  413.0  13.739188  18.145870   11.0  0.365935
# 3        *2  301  10.013307  197.0   6.553560   8.655536   66.0  2.195609
# 4       *41  142   4.723886   85.0   2.827678   3.734622   40.0  1.330672
#
#      AF_GA_I   AC_M      AF_M  AF_GA_M  activity_value            function
# 0   3.030303   80.0  2.661344    20.00            0.25  Decreased function
# 1  37.575758  122.0  4.058550    30.50            1.00     Normal function
# 2   3.333333  105.0  3.493014    26.25            0.25  Decreased function
# 3  20.000000   38.0  1.264138     9.50            1.00     Normal function
# 4  12.121212   17.0  0.565536     4.25            0.50  Decreased function

# %%
haplotype_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 0 to 34
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   haplotype       35 non-null     object
#  1   AC              35 non-null     int64
#  2   AF              35 non-null     float64
#  3   AC_C            35 non-null     float64
#  4   AF_C            35 non-null     float64
#  5   AF_GA_C         35 non-null     float64
#  6   AC_I            35 non-null     float64
#  7   AF_I            35 non-null     float64
#  8   AF_GA_I         35 non-null     float64
#  9   AC_M            35 non-null     float64
#  10  AF_M            35 non-null     float64
#  11  AF_GA_M         35 non-null     float64
#  12  activity_value  23 non-null     float64
#  13  function        35 non-null     object
# dtypes: float64(11), int64(1), object(2)
# memory usage: 4.1+ KB

# %% [markdown]
# # Export TSV and parquet for both diplotype and haplotype tables

# %%
output_dir = Path("output")
dip_file_name = "3_diplotypes"
hap_file_name = "3_haplotypes"

if not output_dir.exists():
    output_dir.mkdir()

# Export diplotypes
diplotype_df.to_csv(output_dir / f"{dip_file_name}.tsv", sep="\t", index=False)
diplotype_df.to_parquet(output_dir / f"{dip_file_name}.parquet", index=False)

# Export haplotypes
haplotype_df.to_csv(output_dir / f"{hap_file_name}.tsv", sep="\t", index=False)
haplotype_df.to_parquet(output_dir / f"{hap_file_name}.parquet", index=False)

# %%
haplotype_df['AC'].sum() /2
# Out:
# 1503.0
